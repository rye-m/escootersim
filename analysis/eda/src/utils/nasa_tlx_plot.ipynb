# %% [markdown]
# # NASA TLX

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# import data
qual_results = pd.read_csv("/Users/ryem/Downloads/Scooterseim Aug 27 2024.csv")
qual_results

# get average of every col with Q159 <Test Ride>
q159 = qual_results.filter(regex='Q159_*')
q159 = q159.filter(regex='Q159_.*[^DO]')
q159 = q159.drop(0)
q159 = q159.drop(1)
q159 = q159.dropna().astype(int)
# q159
# get average of every col with Q149 <Song + Phone>
q149 = qual_results.filter(regex='Q149_*')
q149 = q149.filter(regex='Q149_.*[^DO]')
# q149 = q149.drop('Q149_4_TEXT', axis='columns')
q149 = q149.drop(0)
q149 = q149.drop(1)
q149 = q149.dropna().astype(int) 

# get average of every col with Q145 <Song + Watch>
q145 = qual_results.filter(regex='Q145_*')
q145 = q145.filter(regex='Q145_.*[^DO]')
q145 = q145.drop(0)
q145 = q145.drop(1)
q145 = q145.dropna().astype(int)

# get average of every col with Q125 <Song + Footbutton>
q125 = qual_results.filter(regex='Q125_*')
q125 = q125.filter(regex='Q125_.*[^DO]')
q125 = q125.drop(0)
q125 = q125.drop(1)
q125 = q125.dropna().astype(int) 

# get average of every col with Q153 <Nback + Phone>
q153 = qual_results.filter(regex='Q153_*')
q153 = q153.filter(regex='Q153_.*[^DO]')
q153 = q153.drop(0)
q153 = q153.drop(1)
q153 = q153.dropna().astype(int) 

# get average of every col with Q121 <Song + Voice>
q121 = qual_results.filter(regex='Q121_*')
q121 = q121.filter(regex='Q121_.*[^DO]')
q121 = q121.drop(0)
q121 = q121.drop(1)
q121 = q121.dropna().astype(int) 

# get average of every col with Q117 <Song + Button>
q117 = qual_results.filter(regex='Q117_*')
q117 = q117.filter(regex='Q117_.*[^DO]')
q117 = q117.drop(0)
q117 = q117.drop(1)
q117 = q117.dropna().astype(int) 

# get average of every col with Q109 <Song + Throttle>
q109 = qual_results.filter(regex='Q109_*')
q109 = q109.filter(regex='Q109_.*[^DO]')
q109 = q109.drop(0)
q109 = q109.drop(1)
q109 = q109.dropna().astype(int) 

# get average of every col with Q143 <Nback + Watch>
q143 = qual_results.filter(regex='Q143_*')
q143 = q143.filter(regex='Q143_.*[^DO]')
q143 = q143.drop(0)
q143 = q143.drop(1)
q143 = q143.dropna().astype(int) 

# get average of every col with Q137 <Nback + Footbutton>
q137 = qual_results.filter(regex='Q137_*')
q137 = q137.filter(regex='Q137_.*[^DO]')
q137 = q137.drop(0)
q137 = q137.drop(1)
q137 = q137.dropna().astype(int) 

# get average of every col with Q135 <Nback + Voice>
q135 = qual_results.filter(regex='Q135_*')
q135 = q135.filter(regex='Q135_.*[^DO]')
q135 = q135.drop(0)
q135 = q135.drop(1)
q135 = q135.dropna().astype(int) 

# get average of every col with Q139 <Nback + Button>
q139 = qual_results.filter(regex='Q139_*')
q139 = q139.filter(regex='Q139_.*[^DO]')
q139 = q139.drop(0)
q139 = q139.drop(1)
q139 = q139.dropna().astype(int) 

# get average of every col with Q133 <Nback + Throttle>
q133 = qual_results.filter(regex='Q133_*')
q133 = q133.filter(regex='Q133_.*[^DO]')
q133 = q133.drop(0)
q133 = q133.drop(1)
q133 = q133.dropna().astype(int) 

# Create a single figure with a 4x3 grid of subplots
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(20, 15))

# List of all DataFrames
data_list = [q149, q145, q125, q153, q121, q117, q109, q143, q137, q135, q139, q133]
# List of all axes
ax_list = axes.flatten()

# Plot each DataFrame on the corresponding subplot
for data, ax in zip(data_list, ax_list):
    sns.boxplot(data=data, orient='h', ax=ax)

# Define common labels
x_label = '1 = Very Low, 4 = Moderate, 7 = Very High'
# y_label = 'Interface Order'

# Set common x-axis label for all plots
fig.text(0.5, 0.04, x_label, ha='center')

# Convert the list to a single string for y-axis label
questionnaire_order_str = ', '.join(['Mental demand', 'Physical demand', 'Temporal demand', 'Performance', 'Effort', 'Frustration'])
interfaceXtask_order_lst = ['Song + Phone', 'Song + Watch', 'Song + Footbutton', 'Nback + Phone', 'Song + Voice', 'Song + Button', 'Song + Throttle', 'Nback + Watch', 'Nback + Footbutton', 'Nback + Voice', 'Nback + Button', 'Nback + Throttle']
# Set y-axis labels for all subplots
i = 0
for ax in ax_list:
    ax.set_yticklabels(questionnaire_order_str.split(', '))
    ax.set_title(interfaceXtask_order_lst[i])
    i += 1

# Improve layout
plt.tight_layout(rect=[0.05, 0.1, 0.95, 0.9])  # Adjust layout to fit common labels

# Save the figure
plt.savefig("../figures/qual_results_nasatlx_boxplot.png", dpi=300)

# Show the plot
plt.show()
# Out:
#     Q159_1  Q159_2  Q159_3  Q159_4  Q159_5  Q159_6
# 3        3       5       6       6       5       3
# 4        1       3       1       1       3       1
# 5        1       2       1       3       1       1
# 6        6       5       1       7       4       2
# 7        6       4       2       3       6       4
# 8        3       5       1       5       5       4
# 9        6       7       5       1       6       7
# 10       1       4       1       6       4       1
# 11       7       6       6       4       6       6
# 12       5       4       1       6       4       2
# 13       2       4       2       4       4       2
# 14       5       7       2       1       7       5
# 15       4       7       2       4       5       3
# 17       3       3       1       2       5       6
# 18       3       5       4       5       5       3
# 19       7       5       4       1       7       7
# 20       5       5       3       3       5       5
# 21       6       2       5       4       5       2
# 22       3       5       3       4       5       3
# 23       3       6       4       3       5       4
# 24       5       7       3       4       7       7
# 25       2       4       2       1       7       2
# 26       5       5       2       2       5       4
# 27       7       2       3       2       2       5
# 28       6       5       5       6       6       6
# 29       4       5       4       4       5       4
# 30       4       4       1       6       5       5
# 31       2       5       1       5       6       5
# 32       6       6       2       2       7       6
# 33       6       6       4       3       6       4
# 34       6       6       6       2       7       7
# 35       7       6       3       4       7       2
# 36       3       5       1       6       3       3

# %%
qual_results
# Out:
#                                          RecordedDate  \
# 0                                       Recorded Date
# 1   {"ImportId":"recordedDate","timeZone":"America...
# 2                                 2024-08-05 13:16:12
# 3                                 2024-08-09 13:32:06
# 4                                 2024-08-09 14:52:43
# 5                                 2024-08-10 13:04:12
# 6                                 2024-08-12 10:48:00
# 7                                 2024-08-13 14:00:14
# 8                                 2024-08-13 16:44:34
# 9                                 2024-08-14 09:29:05
# 10                                2024-08-14 09:52:33
# 11                                2024-08-14 12:39:16
# 12                                2024-08-14 18:39:57
# 13                                2024-08-15 09:18:42
# 14                                2024-08-15 12:54:30
# 15                                2024-08-15 14:53:19
# 16                                2024-08-15 18:50:33
# 17                                2024-08-16 13:52:31
# 18                                2024-08-16 15:50:23
# 19                                2024-08-17 09:49:58
# 20                                2024-08-17 12:11:54
# 21                                2024-08-19 08:29:33
# 22                                2024-08-19 12:13:16
# 23                                2024-08-19 14:38:56
# 24                                2024-08-19 16:07:57
# 25                                2024-08-20 09:40:16
# 26                                2024-08-20 12:37:29
# 27                                2024-08-20 18:56:01
# 28                                2024-08-21 05:59:03
# 29                                2024-08-21 07:05:36
# 30                                2024-08-21 13:02:28
# 31                                2024-08-22 07:48:50
# 32                                2024-08-22 09:53:10
# 33                                2024-08-22 12:38:05
# 34                                2024-08-23 10:59:17
# 35                                2024-08-23 12:57:18
# 36                                2024-08-26 11:28:20
#
#                                              Q36  \
# 0   Were there any that were uniquely difficult?
# 1                           {"ImportId":"QID39"}
# 2                        Phone,Watch,Foot Button
# 3                              Watch,Foot Button
# 4                                    Phone,Watch
# 5                                          Watch
# 6                                    Phone,Watch
# 7                                          Watch
# 8                              Watch,Foot Button
# 9                              Watch,Foot Button
# 10                                           NaN
# 11                       Phone,Watch,Foot Button
# 12                                           NaN
# 13                          Phone,Watch,Throttle
# 14                       Phone,Watch,Foot Button
# 15                       Phone,Watch,Foot Button
# 16                                           NaN
# 17                                         Watch
# 18                                         Watch
# 19                       Phone,Watch,Foot Button
# 20                             Watch,Foot Button
# 21                                         Watch
# 22                                         Watch
# 23                                         Watch
# 24                                         Watch
# 25                       Phone,Watch,Foot Button
# 26                                         Watch
# 27                                         Watch
# 28                                   Phone,Watch
# 29                             Watch,Foot Button
# 30                             Watch,Foot Button
# 31                                           NaN
# 32                             Watch,Foot Button
# 33                          Phone,Watch,Throttle
# 34                          Phone,Watch,Throttle
# 35                       Phone,Watch,Foot Button
# 36                                         Watch
#
#                                              Q37  \
# 0   Were there any that were uniquely intuitive?
# 1                           {"ImportId":"QID40"}
# 2                                         Button
# 3                                   Voice,Button
# 4                                    Foot Button
# 5                                   Voice,Button
# 6                       Voice,Foot Button,Button
# 7                                          Voice
# 8                                          Voice
# 9                                   Voice,Button
# 10                                           NaN
# 11                               Throttle,Button
# 12                                           NaN
# 13                                  Voice,Button
# 14                                         Voice
# 15                         Voice,Throttle,Button
# 16                                           NaN
# 17                                      Throttle
# 18                                   Foot Button
# 19                               Throttle,Button
# 20                               Throttle,Button
# 21                                        Button
# 22                               Throttle,Button
# 23                            Voice,Phone,Button
# 24                                      Throttle
# 25                                        Button
# 26                                         Voice
# 27                                        Button
# 28                                         Voice
# 29                                        Button
# 30                                        Button
# 31                                           NaN
# 32                                  Voice,Button
# 33                            Foot Button,Button
# 34                                         Voice
# 35                                  Voice,Button
# 36                      Voice,Foot Button,Button
#
#                                              Q35_1  \
# 0   Could you rank the interfaces you used - Voice
# 1                           {"ImportId":"QID38_1"}
# 2                                                2
# 3                                                1
# 4                                                2
# 5                                                1
# 6                                                2
# 7                                                1
# 8                                                1
# 9                                                3
# 10                                             NaN
# 11                                               2
# 12                                             NaN
# 13                                               1
# 14                                               1
# 15                                               3
# 16                                             NaN
# 17                                               2
# 18                                               3
# 19                                               3
# 20                                               3
# 21                                               2
# 22                                               3
# 23                                               2
# 24                                               2
# 25                                               2
# 26                                               1
# 27                                               4
# 28                                               1
# 29                                               2
# 30                                               2
# 31                                             NaN
# 32                                               2
# 33                                               3
# 34                                               1
# 35                                               1
# 36                                               2
#
#                                              Q35_2  \
# 0   Could you rank the interfaces you used - Phone
# 1                           {"ImportId":"QID38_2"}
# 2                                                5
# 3                                                4
# 4                                                5
# 5                                                5
# 6                                                5
# 7                                                3
# 8                                                5
# 9                                                4
# 10                                             NaN
# 11                                               4
# 12                                             NaN
# 13                                               5
# 14                                               5
# 15                                               6
# 16                                             NaN
# 17                                               5
# 18                                               5
# 19                                               5
# 20                                               4
# 21                                               5
# 22                                               5
# 23                                               3
# 24                                               4
# 25                                               6
# 26                                               5
# 27                                               5
# 28                                               5
# 29                                               6
# 30                                               4
# 31                                             NaN
# 32                                               4
# 33                                               5
# 34                                               6
# 35                                               5
# 36                                               5
#
#                                              Q35_3  \
# 0   Could you rank the interfaces you used - Watch
# 1                           {"ImportId":"QID38_3"}
# 2                                                6
# 3                                                6
# 4                                                6
# 5                                                6
# 6                                                6
# 7                                                6
# 8                                                6
# 9                                                5
# 10                                             NaN
# 11                                               5
# 12                                             NaN
# 13                                               6
# 14                                               6
# 15                                               5
# 16                                             NaN
# 17                                               6
# 18                                               6
# 19                                               6
# 20                                               6
# 21                                               6
# 22                                               6
# 23                                               6
# 24                                               6
# 25                                               5
# 26                                               6
# 27                                               6
# 28                                               6
# 29                                               5
# 30                                               5
# 31                                             NaN
# 32                                               5
# 33                                               6
# 34                                               5
# 35                                               4
# 36                                               6
#
#                                                 Q35_4  \
# 0   Could you rank the interfaces you used - Foot ...
# 1                              {"ImportId":"QID38_4"}
# 2                                                   4
# 3                                                   5
# 4                                                   3
# 5                                                   4
# 6                                                   3
# 7                                                   4
# 8                                                   4
# 9                                                   6
# 10                                                NaN
# 11                                                  6
# 12                                                NaN
# 13                                                  3
# 14                                                  4
# 15                                                  4
# 16                                                NaN
# 17                                                  4
# 18                                                  4
# 19                                                  4
# 20                                                  5
# 21                                                  3
# 22                                                  4
# 23                                                  5
# 24                                                  5
# 25                                                  4
# 26                                                  3
# 27                                                  3
# 28                                                  4
# 29                                                  4
# 30                                                  6
# 31                                                NaN
# 32                                                  6
# 33                                                  2
# 34                                                  2
# 35                                                  6
# 36                                                  3
#
#                                                 Q35_5  \
# 0   Could you rank the interfaces you used - Throttle
# 1                              {"ImportId":"QID38_5"}
# 2                                                   3
# 3                                                   3
# 4                                                   4
# 5                                                   3
# 6                                                   4
# 7                                                   5
# 8                                                   3
# 9                                                   2
# 10                                                NaN
# 11                                                  1
# 12                                                NaN
# 13                                                  4
# 14                                                  3
# 15                                                  2
# 16                                                NaN
# 17                                                  1
# 18                                                  2
# 19                                                  2
# 20                                                  2
# 21                                                  4
# 22                                                  2
# 23                                                  4
# 24                                                  1
# 25                                                  3
# 26                                                  4
# 27                                                  2
# 28                                                  2
# 29                                                  3
# 30                                                  3
# 31                                                NaN
# 32                                                  3
# 33                                                  4
# 34                                                  4
# 35                                                  3
# 36                                                  4
#
#                                               Q35_6                 randomID  \
# 0   Could you rank the interfaces you used - Button                 randomID
# 1                            {"ImportId":"QID38_6"}  {"ImportId":"randomID"}
# 2                                                 1                      NaN
# 3                                                 2                     1011
# 4                                                 1                     3844
# 5                                                 2                      641
# 6                                                 1                     2808
# 7                                                 2                     9570
# 8                                                 2                      725
# 9                                                 1                     1453
# 10                                              NaN                     9880
# 11                                                3                     1026
# 12                                              NaN                     3589
# 13                                                2                     5778
# 14                                                2                      321
# 15                                                1                       91
# 16                                              NaN                     4419
# 17                                                3                     6167
# 18                                                1                      840
# 19                                                1                     2750
# 20                                                1                     3864
# 21                                                1                     5995
# 22                                                1                     8880
# 23                                                1                     1676
# 24                                                3                     8001
# 25                                                1                     6795
# 26                                                2                     3890
# 27                                                1                       67
# 28                                                3                     8867
# 29                                                1                      837
# 30                                                1                     8655
# 31                                              NaN                     8135
# 32                                                1                     5174
# 33                                                1                     8559
# 34                                                3                     2297
# 35                                                2                       61
# 36                                                1                     6333
#
#     ...                                                Q87  \
# 0   ...             Describe any issues with the simulator
# 1   ...                          {"ImportId":"QID87_TEXT"}
# 2   ...                                                NaN
# 3   ...                                                NaN
# 4   ...                                                NaN
# 5   ...                                                NaN
# 6   ...                                                NaN
# 7   ...                                                NaN
# 8   ...                                                NaN
# 9   ...                                                NaN
# 10  ...                                                NaN
# 11  ...                                                NaN
# 12  ...                                                NaN
# 13  ...                                                NaN
# 14  ...                                                NaN
# 15  ...                                     Restarted once
# 16  ...                                                NaN
# 17  ...                                                NaN
# 18  ...                                                NaN
# 19  ...                                                NaN
# 20  ...                                                NaN
# 21  ...                                                NaN
# 22  ...                                                NaN
# 23  ...                                                NaN
# 24  ...                                                NaN
# 25  ...                                                NaN
# 26  ...                                                NaN
# 27  ...                                                NaN
# 28  ...                                                NaN
# 29  ...                                                NaN
# 30  ...                                                NaN
# 31  ...                                                NaN
# 32  ...                                                NaN
# 33  ...                                                NaN
# 34  ...                                                NaN
# 35  ...                                                NaN
# 36  ...  Restart ed the session because of physics engi...
#
#                                                   Q88  \
# 0                     Any other notes or observations
# 1                           {"ImportId":"QID88_TEXT"}
# 2                                                 NaN
# 3                                    Finished earlier
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                         His foot was on the floor/
# 14                           Confused with yes and no
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  Fell off a little once and was slow to respond...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28              Was still s Little wobbly but better
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#                                                   Q90  \
# 0   Did the participant need to practice with the ...
# 1                                {"ImportId":"QID90"}
# 2                                                 NaN
# 3                                          Not at all
# 4                                          Not at all
# 5                                          Not at all
# 6                                          Not at all
# 7                                          Not at all
# 8                                          Not at all
# 9                                          Not at all
# 10                                                NaN
# 11                                         Not at all
# 12                                         Not at all
# 13                                         Not at all
# 14                                         Not at all
# 15                                         Not at all
# 16                                                NaN
# 17                                         Not at all
# 18                                         Not at all
# 19                                         Not at all
# 20                                         Not at all
# 21                                         Not at all
# 22                                                NaN
# 23                                         Not at all
# 24                                         Not at all
# 25                                         Not at all
# 26                                         Not at all
# 27                                         Not at all
# 28                                         Not at all
# 29                                         Not at all
# 30                                         Not at all
# 31                                         Not at all
# 32                                         Not at all
# 33                                         Not at all
# 34                                         Not at all
# 35                            They practiced a little
# 36                                         Not at all
#
#                                            Q91  \
# 0   Were there difficulties with the simulator
# 1                         {"ImportId":"QID91"}
# 2                                          NaN
# 3                                           No
# 4                                           No
# 5                                           No
# 6                                           No
# 7                                           No
# 8                                           No
# 9                                           No
# 10                                         NaN
# 11                                          No
# 12                                          No
# 13                                          No
# 14                                          No
# 15                                          No
# 16                                         NaN
# 17                                          No
# 18                                          No
# 19                                          No
# 20                                          No
# 21                                          No
# 22                                          No
# 23                                          No
# 24                                          No
# 25                                         NaN
# 26                                          No
# 27                                          No
# 28                                          No
# 29                                          No
# 30                                          No
# 31                                          No
# 32                                          No
# 33                                          No
# 34                                          No
# 35                                          No
# 36                                          No
#
#                                                   Q92  \
# 0              Describe any issues with the simulator
# 1                           {"ImportId":"QID92_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4   Sim: kill the app and needed to start it again...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                           The handle bar was broken
# 10                                                NaN
# 11                                                NaN
# 12                                     Restarted once
# 13                   Needed to restart the esp32 once
# 14                          Needed to restart the sim
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                  Restart sim once
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                   Restart sim once
# 24                                  Restart sim once
# 25                   Needed to restart the esp32 once
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  Insta360 had an SD card error so I restarted r...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                   Restart sim once
# 36                                                NaN
#
#                                                   Q93  \
# 0                     Any other notes or observations
# 1                           {"ImportId":"QID93_TEXT"}
# 2                       Swapping out the foot button
# 3                                     Missed one task
# 4                                                 NaN
# 5                                                 NaN
# 6   His driving speed is getting faster and faster \n
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                           Crushed to the building
# 13                                                NaN
# 14                                                NaN
# 15                                  After the cones,
# 16                                                NaN
# 17  When he lost balance he kept foot on floor to ...
# 18                                                NaN
# 19             Appears very confident with the system
# 20                                                NaN
# 21                        Her Driving was so reckless
# 22                                                NaN
# 23  She was standing slightly cross legged to main...
# 24                                                NaN
# 25                                  They ride slowly
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                             She drove very slowly
# 33  Did the task relatively faster compared to oth...
# 34  Much faster with this than the others and was ...
# 35  Was more reasonable with driving 2nd time arou...
# 36                                                NaN
#
#                                                  Q105  \
# 0   Did the participant need to practice with the ...
# 1                               {"ImportId":"QID105"}
# 2                                          Not at all
# 3                                          Not at all
# 4                                          Not at all
# 5                                          Not at all
# 6                                          Not at all
# 7                             They practiced a little
# 8                                          Not at all
# 9                                          Not at all
# 10                                                NaN
# 11                                         Not at all
# 12                                                NaN
# 13                                         Not at all
# 14                                         Not at all
# 15                                         Not at all
# 16                                                NaN
# 17                                         Not at all
# 18                                         Not at all
# 19                            They practiced a little
# 20                                         Not at all
# 21                                         Not at all
# 22                                         Not at all
# 23                                         Not at all
# 24                                         Not at all
# 25                                         Not at all
# 26                                         Not at all
# 27                                         Not at all
# 28                                         Not at all
# 29                                         Not at all
# 30                                         Not at all
# 31                                                NaN
# 32                                         Not at all
# 33                                         Not at all
# 34                                         Not at all
# 35                                         Not at all
# 36                                         Not at all
#
#                                           Q106  \
# 0   Were there difficulties with the simulator
# 1                        {"ImportId":"QID106"}
# 2                                           No
# 3                                           No
# 4                                           No
# 5                                           No
# 6                                           No
# 7                                           No
# 8                                           No
# 9                                           No
# 10                                         NaN
# 11                                          No
# 12                                         NaN
# 13                                         NaN
# 14                                          No
# 15                                          No
# 16                                         NaN
# 17                                          No
# 18                                          No
# 19                                          No
# 20                                          No
# 21                                          No
# 22                                          No
# 23                                          No
# 24                                          No
# 25                                         Yes
# 26                                          No
# 27                                          No
# 28                                          No
# 29                                          No
# 30                                          No
# 31                                         NaN
# 32                                          No
# 33                                          No
# 34                                          No
# 35                                          No
# 36                                          No
#
#                                                  Q107  \
# 0              Describe any issues with the simulator
# 1                          {"ImportId":"QID107_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  The camera had a problem, so I swapped the camera
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                   Restart sim once
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34          Had to restart microcontroller /sim twice
# 35                                  Restart sim once
# 36                                                NaN
#
#                                                  Q108
# 0                     Any other notes or observations
# 1                          {"ImportId":"QID108_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4   Looks he had difficulty for using Prototype wi...
# 5                                                 NaN
# 6   When he stepped down it took more time to answ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                      Crashed into garbage cans (1)
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  Struggled to maintain balance while inputting ...
# 18  Seems like it is difficult to use this throttl...
# 19  Appeared more comfortable than before using th...
# 20                    Asked me if he can use shortcut
# 21  She had difficulty between short twist and lon...
# 22                                                NaN
# 23                                                NaN
# 24       Tries to look side by side at intersections
# 25                                                NaN
# 26                                           Speeding
# 27  He chanced his foot position and face to the s...
# 28  Much more confident, was able to give input wh...
# 29  She looks confused when she use this for the f...
# 30                                                NaN
# 31                                                NaN
# 32                             She drove very slowly
# 33  Got a little out of balance while riding with ...
# 34             Immediately better than the first time
# 35           Lost balance and couldn’t input one time
# 36                                                NaN
#
# [37 rows x 89 columns]
